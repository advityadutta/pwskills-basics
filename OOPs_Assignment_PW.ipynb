# %% [markdown]
# # Python OOPs
#
#
#
# 1. What is Object-Oriented Programming (OOP)?
#
#
# - OOP is a programming style where code is written using objects that represents real world things. It focuses on data and behavious together.
#
#
# 2. What is a class in OOP?
#
# - A class is a blueprint or template for creating objects. It is used to define variables and methods.
#
#
# 3. What is an object in OOP?
#
# - An object is a real instance of a class. it uses properties and methods defined in class
#
#
# 4. What is the difference between abstraction and encapsulation?
#
#
#
# - Abstraction is the process of hiding the complex implementation details and showing only the essential features of an object. It allows you to represent essential features of an object while hiding unnecessary details. This helps in managing complexity by separating what an object does (methods) from how it achieves it (implementation details).
#
#
#
# - Encapsulation is the concept of bundling data (attributes) and methods (functions) that operate on that data into a single unit, known as a class. It restricts direct access to some components of an object and provides controlled access through methods. This helps in protecting the internal state of an object from unintended interference and misuse.
#
# 5. What are dunder methods in Python?
#
#
# - Dunder (double underscore) methods are special methods, which allow pyhon objects to behave like built-in types. eg: __init__, __str__,__add__
#
# 6. Explain the concept of inheritance in OOP?
#
# - Inheritance allows one class (child) to use properties of another class (parent), which helps in code reuse.
#
#
#
# 7. What is polymorphism in OOP?
#
# - Polymorphism means same method name, different behaviour. This works differently depending on object.
#
# 8. How is encapsulation achieved in Python?
#
# - using private variables (__variable__)
# - Using getters and setters
# - Controlling access to data
#
# 9. What is a constructor in Python?
#
# - Constructor is a special method called __init__, it runs automatically when an object is created.
#
# 10. What are class and static methods in Python?
#
# - Class method: works with class variables (@classmethod)
#
# - Static method: independent of class & object (@staticmethod)
#
# 11. What is method overloading in Python?
#
# - Python does not support traditional overloading (multiple methods with the same name but different parameters).
#
# Instead, it uses:
#
# - Default arguments
#
# - Variable-length arguments
#
#
# 12. What is method overriding in OOP?
#
# - When a child class redefines a method of the parent class to change its behavior.
#
# 13. What is a property decorator in Python?
#
# - @property allows a method to be accessed like a variable, while still applying logic internally.
#
# 14. Why is polymorphism important in OOP?
#
# Because it:
#
# - Improves flexibility
#
# - Reduces code duplication
#
# - Makes code easier to extend
#
# 15. What is an abstract class in Python?
#
# An abstract class:
#
# - Cannot be instantiated
#
# - Contains abstract methods
#
# - Forces child classes to implement methods
#
# - Uses abc module
#
# 16. What are the advantages of OOP?
#
# - Code reusability
#
# - Easy maintenance
#
# - Better structure
#
# - Real-world modeling
#
# - Scalability
#
#
# 17. What is the difference between a class variable and an instance variable?
#
# - Class Variable is shared by all objects unlike instance variable, which is unique to each object.
#
# - Class Variable is defined in class, while instance variable is defined in constructor.
#
# 18. What is multiple inheritance in Python?
#
# - When a class inherits from more than one parent class.
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
#
# - "__str__" : User-friendly output
#
# - "__repr__": Developer/debug output
#
# 20. What is the significance of the ‘super()’ function in Python?
#
#
# super() allows a child class to:
#
# - Call parent class methods
#
# - Avoid duplicate code
#
# - Support multiple inheritance
#
# 21. What is the significance of the __del__ method in Python?
#
# - "__del__" is called when an object is destroyed.
# - Used for cleanup (closing files, releasing resources).
#
#
# 22. What is the difference between @staticmethod and @classmethod in Python?
#
# - @staticmethod has no class reference, while @classmethod uses 'cls'.
#
# - Static is a utility function while class method works on class data.
#
# - Static is independent while class method is class aware.
#
#
# 23. How does polymorphism work in Python with inheritance?
#
# - A parent method behaves differently when called by different child objects.
#
# - Python decides at runtime which method to call.
#
# 24. What is method chaining in Python OOP?
#
# - Method chaining means calling multiple methods in one line by returning 'self'.
#
# 25. What is the purpose of the __call__ method in Python?
#
# - "__call__" allows an object to be called like a function.

# %% [markdown]
# # Practical Questions

# %% [markdown]
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# %%
Dog().speak()
# Out:
# Bark!

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def area(self, radius):
        return math.pi * radius * radius

class Rectangle(Shape):
    def area(self, length, width):
        return length * width

# %%
Rectangle.area(1,10,20)
# Out:
# 200

# %%
Circle.area(1,3)
# Out:
# 28.274333882308138

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

# %% [markdown]
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")


Sparrow().fly()
Penguin().fly()
# Out:
# Sparrow flies high
# Penguin cannot fly

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self):
        self.__balance = 0

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def check_balance(self):
        return self.__balance

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):
    def play(self):
        print("Guitar is playing")

class Piano(Instrument):
    def play(self):
        print("Piano is playing")

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() and a static method subtract_numbers().

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %% [markdown]
# 8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

# %% [markdown]
# 11. Create a class Person with attributes name and age and a greet() method.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %% [markdown]
# 12. Implement a class Student with attributes name and grades and a method average_grade().

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() and area().

# %%
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# %% [markdown]
# 14. Create a class Employee and derived class Manager that adds a bonus.

# %%
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return super().calculate_salary(hours, rate) + bonus

# %% [markdown]
# 15. Create a class Product and implement total_price().

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# %% [markdown]
# 16. Create an abstract class Animal with sound() method and derived classes Cow and Sheep.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

# %% [markdown]
# 17. Create a class Book with get_book_info() method.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"{self.title} by {self.author} ({self.year_published})"

# %% [markdown]
# 18. Create a class House and derived class Mansion.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
